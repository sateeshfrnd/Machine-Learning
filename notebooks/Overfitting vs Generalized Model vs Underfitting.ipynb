# %% [markdown]
# # Overfitting vs Generalized Model vs Underfitting
#
# In machine learning, the balance between underfitting, a generalized model, and overfitting is critical to building a good model
#
#
# - **Underfitting**:
#   - The model is too simple to capture the underlying patterns in the data.
#   - It performs poorly on both training and validation data.
#
# - **Overfitting**:
#   - The model learns **too much detail** from the training data, including noise.
#   - It performs well on the training data but poorly on unseen (validation) data.
#
# - **Generalized Model**:
#   - The model captures the **right patterns** in the data without overfitting or underfitting.
#   - It performs well on both training and unseen (validation) data.

# %% [markdown]
# ## import required modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## Sample Data

# %%
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([1, 4, 9, 16, 25])

# %% [markdown]
# ## Models

# %%
underfit_model = make_pipeline(PolynomialFeatures(1), LinearRegression())  # Linear
generalized_model = make_pipeline(PolynomialFeatures(2), LinearRegression())  # Quadratic
overfit_model = make_pipeline(PolynomialFeatures(10), LinearRegression())  # Overfitting

# %% [markdown]
# ## Fit models

# %%
underfit_model.fit(X, y)
generalized_model.fit(X, y)
overfit_model.fit(X, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=10)),
#                 ('linearregression', LinearRegression())])

# %% [markdown]
# ## Predictions

# %%
X_pred = np.linspace(1, 5, 100).reshape(-1, 1)
y_underfit = underfit_model.predict(X_pred)
y_generalized = generalized_model.predict(X_pred)
y_overfit = overfit_model.predict(X_pred)

# %% [markdown]
# # Visualize

# %%
plt.scatter(X, y, color='red', label='Data Points')
plt.plot(X_pred, y_underfit, label='Underfitting (Linear)', color='blue')
plt.plot(X_pred, y_generalized, label='Generalized (Quadratic)', color='green')
plt.plot(X_pred, y_overfit, label='Overfitting (10th Degree)', color='orange')
plt.legend()
plt.title('Underfitting vs Generalization vs Overfitting')
plt.show()
